# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
from tensorflow.keras.applications import vgg16
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras import optimizers, losses
import seaborn as sns
import pandas as pd
import numpy as np

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  'C:/DS/Netology/Diploma/data/train',
  #validation_split=0.2,
  #subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 33984 files belonging to 4 classes.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  'C:/DS/Netology/Diploma/Data/val',
  #validation_split=0.2,
  #subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6400 files belonging to 4 classes.

# %%
num_class = len(train_ds.class_names)

# %%
 plt.figure(figsize=(10, 10))
 for images, labels in train_ds.take(1):
     for i in range(9):
         ax = plt.subplot(3, 3, i + 1)
         plt.imshow(images[i].numpy().astype("uint8"))
         plt.title(train_ds.class_names[labels[i]])
         plt.axis("off")

# %%
model1 = tf.keras.models.Sequential([
    Conv2D(16, (3,3), activation = 'relu', input_shape = (224,224, 3)),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation = 'relu'),
    Dropout(0.2),
    Dense(4, activation = 'softmax')
])

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 222, 222, 16)      448
#
#  max_pooling2d_4 (MaxPooling  (None, 111, 111, 16)     0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_5 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 52, 52, 32)        9248
#
#  max_pooling2d_6 (MaxPooling  (None, 26, 26, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 32)        9248
#
#  max_pooling2d_7 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_2 (Dense)             (None, 512)               2359808
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,385,444
# Trainable params: 2,385,444
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])

# %%
history1 = model1.fit(train_ds,
    #steps_per_epoch=num_class,
    validation_data=val_ds,
    #validation_steps=num_class,
    epochs=50)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 347s 326ms/step - loss: 1.0981 - accuracy: 0.5639 - val_loss: 0.6014 - val_accuracy: 0.7236
# Epoch 2/50
# 1062/1062 [==============================] - 347s 327ms/step - loss: 0.5306 - accuracy: 0.7717 - val_loss: 0.4269 - val_accuracy: 0.8209
# Epoch 3/50
# 1062/1062 [==============================] - 341s 321ms/step - loss: 0.3498 - accuracy: 0.8559 - val_loss: 0.1611 - val_accuracy: 0.9392
# Epoch 4/50
# 1062/1062 [==============================] - 346s 325ms/step - loss: 0.2492 - accuracy: 0.8993 - val_loss: 0.2391 - val_accuracy: 0.9203
# Epoch 5/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.1921 - accuracy: 0.9247 - val_loss: 0.0749 - val_accuracy: 0.9714
# Epoch 6/50
# 1062/1062 [==============================] - 345s 325ms/step - loss: 0.1596 - accuracy: 0.9410 - val_loss: 0.0775 - val_accuracy: 0.9717
# Epoch 7/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.1364 - accuracy: 0.9482 - val_loss: 0.1128 - val_accuracy: 0.9609
# Epoch 8/50
# 1062/1062 [==============================] - 345s 325ms/step - loss: 0.1142 - accuracy: 0.9594 - val_loss: 0.0678 - val_accuracy: 0.9791
# Epoch 9/50
# 1062/1062 [==============================] - 343s 323ms/step - loss: 0.1041 - accuracy: 0.9627 - val_loss: 0.0719 - val_accuracy: 0.9814
# Epoch 10/50
# 1062/1062 [==============================] - 341s 321ms/step - loss: 0.0926 - accuracy: 0.9666 - val_loss: 0.0811 - val_accuracy: 0.9750
# Epoch 11/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.0843 - accuracy: 0.9713 - val_loss: 0.0834 - val_accuracy: 0.9775
# Epoch 12/50
# 1062/1062 [==============================] - 346s 326ms/step - loss: 0.0872 - accuracy: 0.9699 - val_loss: 0.0907 - val_accuracy: 0.9745
# Epoch 13/50
# 1062/1062 [==============================] - 343s 323ms/step - loss: 0.0836 - accuracy: 0.9713 - val_loss: 0.0672 - val_accuracy: 0.9830
# Epoch 14/50
# 1062/1062 [==============================] - 346s 325ms/step - loss: 0.0709 - accuracy: 0.9778 - val_loss: 0.1000 - val_accuracy: 0.9664
# Epoch 15/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.0625 - accuracy: 0.9799 - val_loss: 0.1174 - val_accuracy: 0.9670
# Epoch 16/50
# 1062/1062 [==============================] - 347s 327ms/step - loss: 0.0699 - accuracy: 0.9775 - val_loss: 0.1279 - val_accuracy: 0.9648
# Epoch 17/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.0603 - accuracy: 0.9807 - val_loss: 0.0587 - val_accuracy: 0.9848
# Epoch 18/50
# 1062/1062 [==============================] - 337s 317ms/step - loss: 0.0705 - accuracy: 0.9773 - val_loss: 0.0930 - val_accuracy: 0.9761
# Epoch 19/50
# 1062/1062 [==============================] - 343s 323ms/step - loss: 0.0622 - accuracy: 0.9811 - val_loss: 0.0529 - val_accuracy: 0.9853
# Epoch 20/50
# 1062/1062 [==============================] - 340s 321ms/step - loss: 0.0615 - accuracy: 0.9805 - val_loss: 0.0412 - val_accuracy: 0.9878
# Epoch 21/50
# 1062/1062 [==============================] - 347s 327ms/step - loss: 0.0550 - accuracy: 0.9825 - val_loss: 0.0959 - val_accuracy: 0.9733
# Epoch 22/50
# 1062/1062 [==============================] - 350s 329ms/step - loss: 0.0686 - accuracy: 0.9796 - val_loss: 0.0405 - val_accuracy: 0.9900
# Epoch 23/50
# 1062/1062 [==============================] - 347s 326ms/step - loss: 0.0505 - accuracy: 0.9845 - val_loss: 0.0249 - val_accuracy: 0.9920
# Epoch 24/50
# 1062/1062 [==============================] - 348s 328ms/step - loss: 0.0599 - accuracy: 0.9820 - val_loss: 0.0561 - val_accuracy: 0.9834
# Epoch 25/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.0464 - accuracy: 0.9862 - val_loss: 0.0722 - val_accuracy: 0.9878
# Epoch 26/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.0542 - accuracy: 0.9835 - val_loss: 0.0191 - val_accuracy: 0.9934
# Epoch 27/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.0484 - accuracy: 0.9847 - val_loss: 0.1137 - val_accuracy: 0.9759
# Epoch 28/50
# 1062/1062 [==============================] - 347s 327ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0867 - val_accuracy: 0.9834
# Epoch 29/50
# 1062/1062 [==============================] - 341s 321ms/step - loss: 0.0540 - accuracy: 0.9841 - val_loss: 0.0227 - val_accuracy: 0.9937
# Epoch 30/50
# 1062/1062 [==============================] - 341s 321ms/step - loss: 0.0425 - accuracy: 0.9872 - val_loss: 0.0420 - val_accuracy: 0.9895
# Epoch 31/50
# 1062/1062 [==============================] - 340s 320ms/step - loss: 0.0515 - accuracy: 0.9859 - val_loss: 0.0788 - val_accuracy: 0.9831
# Epoch 32/50
# 1062/1062 [==============================] - 344s 323ms/step - loss: 0.0395 - accuracy: 0.9887 - val_loss: 0.0551 - val_accuracy: 0.9866
# Epoch 33/50
# 1062/1062 [==============================] - 345s 324ms/step - loss: 0.0555 - accuracy: 0.9843 - val_loss: 0.0759 - val_accuracy: 0.9820
# Epoch 34/50
# 1062/1062 [==============================] - 348s 327ms/step - loss: 0.0460 - accuracy: 0.9871 - val_loss: 0.0399 - val_accuracy: 0.9911
# Epoch 35/50
# 1062/1062 [==============================] - 340s 320ms/step - loss: 0.0475 - accuracy: 0.9878 - val_loss: 0.2826 - val_accuracy: 0.9588
# Epoch 36/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.0402 - accuracy: 0.9888 - val_loss: 0.2909 - val_accuracy: 0.9608
# Epoch 37/50
# 1062/1062 [==============================] - 340s 320ms/step - loss: 0.0421 - accuracy: 0.9888 - val_loss: 0.1033 - val_accuracy: 0.9783
# Epoch 38/50
# 1062/1062 [==============================] - 339s 319ms/step - loss: 0.0537 - accuracy: 0.9850 - val_loss: 0.0463 - val_accuracy: 0.9911
# Epoch 39/50
# 1062/1062 [==============================] - 343s 322ms/step - loss: 0.0398 - accuracy: 0.9893 - val_loss: 0.1885 - val_accuracy: 0.9608
# Epoch 40/50
# 1062/1062 [==============================] - 339s 319ms/step - loss: 0.0310 - accuracy: 0.9915 - val_loss: 0.0573 - val_accuracy: 0.9856
# Epoch 41/50
# 1062/1062 [==============================] - 338s 318ms/step - loss: 0.0533 - accuracy: 0.9861 - val_loss: 0.0532 - val_accuracy: 0.9886
# Epoch 42/50
# 1062/1062 [==============================] - 338s 318ms/step - loss: 0.0445 - accuracy: 0.9883 - val_loss: 0.0259 - val_accuracy: 0.9937
# Epoch 43/50
# 1062/1062 [==============================] - 349s 329ms/step - loss: 0.0454 - accuracy: 0.9885 - val_loss: 0.0326 - val_accuracy: 0.9933
# Epoch 44/50
# 1062/1062 [==============================] - 346s 325ms/step - loss: 0.0389 - accuracy: 0.9892 - val_loss: 0.0687 - val_accuracy: 0.9841
# Epoch 45/50
# 1062/1062 [==============================] - 346s 326ms/step - loss: 0.0379 - accuracy: 0.9897 - val_loss: 0.0453 - val_accuracy: 0.9902
# Epoch 46/50
# 1062/1062 [==============================] - 344s 323ms/step - loss: 0.0357 - accuracy: 0.9915 - val_loss: 0.0321 - val_accuracy: 0.9914
# Epoch 47/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.0531 - accuracy: 0.9872 - val_loss: 0.0251 - val_accuracy: 0.9927
# Epoch 48/50
# 1062/1062 [==============================] - 342s 322ms/step - loss: 0.0293 - accuracy: 0.9922 - val_loss: 0.0477 - val_accuracy: 0.9894
# Epoch 49/50
# 1062/1062 [==============================] - 346s 325ms/step - loss: 0.0418 - accuracy: 0.9891 - val_loss: 0.0808 - val_accuracy: 0.9855
# Epoch 50/50
# 1062/1062 [==============================] - 344s 324ms/step - loss: 0.0429 - accuracy: 0.9884 - val_loss: 0.0424 - val_accuracy: 0.9908

# %%
history1.history['val_accuracy']
# Out:
# [0.7235937714576721,
#  0.8209375143051147,
#  0.9392187595367432,
#  0.9203125238418579,
#  0.9714062213897705,
#  0.9717187285423279,
#  0.9609375,
#  0.9790624976158142,
#  0.9814062714576721,
#  0.9750000238418579,
#  0.9775000214576721,
#  0.9745312333106995,
#  0.9829687476158142,
#  0.9664062261581421,
#  0.9670312404632568,
#  0.96484375,
#  0.9848437309265137,
#  0.9760937690734863,
#  0.9853125214576721,
#  0.9878125190734863,
#  0.9732812643051147,
#  0.9900000095367432,
#  0.9920312762260437,
#  0.9834374785423279,
#  0.9878125190734863,
#  0.9934375286102295,
#  0.9759374856948853,
#  0.9834374785423279,
#  0.9937499761581421,
#  0.9895312786102295,
#  0.9831249713897705,
#  0.9865624904632568,
#  0.9820312261581421,
#  0.9910937547683716,
#  0.9587500095367432,
#  0.9607812762260437,
#  0.9782812595367432,
#  0.9910937547683716,
#  0.9607812762260437,
#  0.9856250286102295,
#  0.9885937571525574,
#  0.9937499761581421,
#  0.9932812452316284,
#  0.9840624928474426,
#  0.9901562333106995,
#  0.991406261920929,
#  0.9926562309265137,
#  0.9893749952316284,
#  0.9854687452316284,
#  0.9907812476158142]

# %%
#Accuracy
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# loss
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model2 = tf.keras.models.Sequential([
    Conv2D(16, (3,3), activation = 'relu', input_shape = (224,224, 3)),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    layers.Dropout(0.25),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    Conv2D(32, (3,3), activation = 'relu'),
    MaxPooling2D(2,2),
    layers.Dropout(0.25),
    Flatten(),
    Dense(512, activation = 'relu'),
    Dropout(0.2),
    Dense(4, activation = 'softmax')
])

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 222, 222, 16)      448
#
#  max_pooling2d_8 (MaxPooling  (None, 111, 111, 16)     0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 109, 109, 32)      4640
#
#  max_pooling2d_9 (MaxPooling  (None, 54, 54, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 54, 54, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 52, 52, 32)        9248
#
#  max_pooling2d_10 (MaxPoolin  (None, 26, 26, 32)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 32)        9248
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 32)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 32)        0
#
#  flatten_2 (Flatten)         (None, 4608)              0
#
#  dense_4 (Dense)             (None, 512)               2359808
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,385,444
# Trainable params: 2,385,444
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])

# %%
history2 = model2.fit(train_ds,
    #steps_per_epoch=num_class,
    validation_data=val_ds,
    #validation_steps=num_class,
    epochs=50)
# Out:
# Epoch 1/50
# 1062/1062 [==============================] - 367s 345ms/step - loss: 1.3772 - accuracy: 0.4526 - val_loss: 0.8025 - val_accuracy: 0.6066
# Epoch 2/50
# 1062/1062 [==============================] - 363s 342ms/step - loss: 0.7271 - accuracy: 0.6766 - val_loss: 0.5781 - val_accuracy: 0.7364
# Epoch 3/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.5433 - accuracy: 0.7673 - val_loss: 0.4324 - val_accuracy: 0.8217
# Epoch 4/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.4313 - accuracy: 0.8219 - val_loss: 0.2821 - val_accuracy: 0.8948
# Epoch 5/50
# 1062/1062 [==============================] - 362s 340ms/step - loss: 0.3624 - accuracy: 0.8528 - val_loss: 0.2462 - val_accuracy: 0.9058
# Epoch 6/50
# 1062/1062 [==============================] - 362s 341ms/step - loss: 0.3142 - accuracy: 0.8743 - val_loss: 0.1096 - val_accuracy: 0.9694
# Epoch 7/50
# 1062/1062 [==============================] - 364s 342ms/step - loss: 0.2704 - accuracy: 0.8936 - val_loss: 0.1226 - val_accuracy: 0.9597
# Epoch 8/50
# 1062/1062 [==============================] - 362s 341ms/step - loss: 0.2446 - accuracy: 0.9055 - val_loss: 0.0937 - val_accuracy: 0.9739
# Epoch 9/50
# 1062/1062 [==============================] - 366s 345ms/step - loss: 0.2110 - accuracy: 0.9191 - val_loss: 0.2984 - val_accuracy: 0.9133
# Epoch 10/50
# 1062/1062 [==============================] - 364s 343ms/step - loss: 0.1924 - accuracy: 0.9281 - val_loss: 0.0439 - val_accuracy: 0.9886
# Epoch 11/50
# 1062/1062 [==============================] - 367s 346ms/step - loss: 0.1773 - accuracy: 0.9350 - val_loss: 0.0875 - val_accuracy: 0.9692
# Epoch 12/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.1677 - accuracy: 0.9369 - val_loss: 0.0420 - val_accuracy: 0.9895
# Epoch 13/50
# 1062/1062 [==============================] - 362s 341ms/step - loss: 0.1514 - accuracy: 0.9441 - val_loss: 0.0716 - val_accuracy: 0.9791
# Epoch 14/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.1446 - accuracy: 0.9483 - val_loss: 0.0340 - val_accuracy: 0.9903
# Epoch 15/50
# 1062/1062 [==============================] - 370s 348ms/step - loss: 0.1444 - accuracy: 0.9493 - val_loss: 0.0793 - val_accuracy: 0.9719
# Epoch 16/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.1311 - accuracy: 0.9524 - val_loss: 0.1251 - val_accuracy: 0.9578
# Epoch 17/50
# 1062/1062 [==============================] - 364s 343ms/step - loss: 0.1230 - accuracy: 0.9572 - val_loss: 0.0479 - val_accuracy: 0.9842
# Epoch 18/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.1213 - accuracy: 0.9568 - val_loss: 0.0298 - val_accuracy: 0.9912
# Epoch 19/50
# 1062/1062 [==============================] - 365s 344ms/step - loss: 0.1164 - accuracy: 0.9607 - val_loss: 0.0871 - val_accuracy: 0.9720
# Epoch 20/50
# 1062/1062 [==============================] - 368s 346ms/step - loss: 0.1106 - accuracy: 0.9609 - val_loss: 0.0247 - val_accuracy: 0.9923
# Epoch 21/50
# 1062/1062 [==============================] - 367s 345ms/step - loss: 0.1124 - accuracy: 0.9617 - val_loss: 0.0916 - val_accuracy: 0.9714
# Epoch 22/50
# 1062/1062 [==============================] - 368s 347ms/step - loss: 0.1137 - accuracy: 0.9617 - val_loss: 0.0557 - val_accuracy: 0.9855
# Epoch 23/50
# 1062/1062 [==============================] - 367s 346ms/step - loss: 0.1042 - accuracy: 0.9644 - val_loss: 0.0149 - val_accuracy: 0.9962
# Epoch 24/50
# 1062/1062 [==============================] - 373s 351ms/step - loss: 0.1050 - accuracy: 0.9650 - val_loss: 0.1007 - val_accuracy: 0.9725
# Epoch 25/50
# 1062/1062 [==============================] - 370s 348ms/step - loss: 0.1014 - accuracy: 0.9653 - val_loss: 0.1140 - val_accuracy: 0.9692
# Epoch 26/50
# 1062/1062 [==============================] - 370s 348ms/step - loss: 0.0987 - accuracy: 0.9676 - val_loss: 0.0515 - val_accuracy: 0.9853
# Epoch 27/50
# 1062/1062 [==============================] - 368s 347ms/step - loss: 0.0893 - accuracy: 0.9702 - val_loss: 0.1356 - val_accuracy: 0.9683
# Epoch 28/50
# 1062/1062 [==============================] - 370s 348ms/step - loss: 0.1017 - accuracy: 0.9653 - val_loss: 0.0281 - val_accuracy: 0.9912
# Epoch 29/50
# 1062/1062 [==============================] - 369s 347ms/step - loss: 0.0915 - accuracy: 0.9701 - val_loss: 0.0276 - val_accuracy: 0.9906
# Epoch 30/50
# 1062/1062 [==============================] - 372s 350ms/step - loss: 0.0867 - accuracy: 0.9714 - val_loss: 0.0333 - val_accuracy: 0.9914
# Epoch 31/50
# 1062/1062 [==============================] - 372s 350ms/step - loss: 0.0880 - accuracy: 0.9717 - val_loss: 0.0823 - val_accuracy: 0.9797
# Epoch 32/50
# 1062/1062 [==============================] - 369s 347ms/step - loss: 0.0824 - accuracy: 0.9723 - val_loss: 0.1989 - val_accuracy: 0.9550
# Epoch 33/50
# 1062/1062 [==============================] - 362s 341ms/step - loss: 0.0822 - accuracy: 0.9726 - val_loss: 0.0283 - val_accuracy: 0.9950
# Epoch 34/50
# 1062/1062 [==============================] - 371s 349ms/step - loss: 0.0827 - accuracy: 0.9744 - val_loss: 0.0259 - val_accuracy: 0.9937
# Epoch 35/50
# 1062/1062 [==============================] - 365s 344ms/step - loss: 0.0787 - accuracy: 0.9737 - val_loss: 0.0905 - val_accuracy: 0.9733
# Epoch 36/50
# 1062/1062 [==============================] - 361s 340ms/step - loss: 0.0777 - accuracy: 0.9751 - val_loss: 0.0187 - val_accuracy: 0.9947
# Epoch 37/50
# 1062/1062 [==============================] - 364s 342ms/step - loss: 0.0783 - accuracy: 0.9761 - val_loss: 0.0306 - val_accuracy: 0.9925
# Epoch 38/50
# 1062/1062 [==============================] - 365s 344ms/step - loss: 0.0747 - accuracy: 0.9751 - val_loss: 0.0960 - val_accuracy: 0.9734
# Epoch 39/50
# 1062/1062 [==============================] - 368s 347ms/step - loss: 0.0780 - accuracy: 0.9758 - val_loss: 0.0234 - val_accuracy: 0.9936
# Epoch 40/50
# 1062/1062 [==============================] - 361s 339ms/step - loss: 0.0709 - accuracy: 0.9773 - val_loss: 0.0374 - val_accuracy: 0.9887
# Epoch 41/50
# 1062/1062 [==============================] - 362s 341ms/step - loss: 0.0748 - accuracy: 0.9763 - val_loss: 0.0119 - val_accuracy: 0.9961
# Epoch 42/50
# 1062/1062 [==============================] - 361s 340ms/step - loss: 0.0727 - accuracy: 0.9777 - val_loss: 0.0489 - val_accuracy: 0.9858
# Epoch 43/50
# 1062/1062 [==============================] - 366s 345ms/step - loss: 0.0826 - accuracy: 0.9731 - val_loss: 0.0951 - val_accuracy: 0.9764
# Epoch 44/50
# 1062/1062 [==============================] - 363s 341ms/step - loss: 0.0628 - accuracy: 0.9796 - val_loss: 0.0134 - val_accuracy: 0.9969
# Epoch 45/50
# 1062/1062 [==============================] - 363s 342ms/step - loss: 0.0703 - accuracy: 0.9786 - val_loss: 0.0262 - val_accuracy: 0.9931
# Epoch 46/50
# 1062/1062 [==============================] - 372s 350ms/step - loss: 0.0792 - accuracy: 0.9751 - val_loss: 0.0236 - val_accuracy: 0.9945
# Epoch 47/50
# 1062/1062 [==============================] - 369s 347ms/step - loss: 0.0640 - accuracy: 0.9801 - val_loss: 0.0076 - val_accuracy: 0.9978
# Epoch 48/50
# 1062/1062 [==============================] - 373s 351ms/step - loss: 0.0740 - accuracy: 0.9768 - val_loss: 0.0057 - val_accuracy: 0.9983
# Epoch 49/50
# 1062/1062 [==============================] - 369s 348ms/step - loss: 0.0696 - accuracy: 0.9789 - val_loss: 0.0580 - val_accuracy: 0.9900
# Epoch 50/50
# 1062/1062 [==============================] - 369s 347ms/step - loss: 0.0671 - accuracy: 0.9787 - val_loss: 0.0133 - val_accuracy: 0.9966

# %%
#Accuracy
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# loss
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
history = model2.fit(val_ds,
    #steps_per_epoch=num_class,
    #validation_data=val_ds,
    #validation_steps=num_class,
    epochs=50)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0727 - accuracy: 0.9797
# Epoch 2/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0845 - accuracy: 0.9772
# Epoch 3/50
# 200/200 [==============================] - 66s 329ms/step - loss: 0.0435 - accuracy: 0.9867
# Epoch 4/50
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0351 - accuracy: 0.9894
# Epoch 5/50
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0334 - accuracy: 0.9897
# Epoch 6/50
# 200/200 [==============================] - 66s 327ms/step - loss: 0.0195 - accuracy: 0.9955
# Epoch 7/50
# 200/200 [==============================] - 66s 329ms/step - loss: 0.0354 - accuracy: 0.9898
# Epoch 8/50
# 200/200 [==============================] - 66s 327ms/step - loss: 0.0397 - accuracy: 0.9884
# Epoch 9/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0273 - accuracy: 0.9909
# Epoch 10/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0497 - accuracy: 0.9875
# Epoch 11/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0327 - accuracy: 0.9900
# Epoch 12/50
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0439 - accuracy: 0.9878
# Epoch 13/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0475 - accuracy: 0.9866
# Epoch 14/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0219 - accuracy: 0.9930
# Epoch 15/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0375 - accuracy: 0.9886
# Epoch 16/50
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0551 - accuracy: 0.9861
# Epoch 17/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0377 - accuracy: 0.9892
# Epoch 18/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0499 - accuracy: 0.9881
# Epoch 19/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0284 - accuracy: 0.9922
# Epoch 20/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0380 - accuracy: 0.9895
# Epoch 21/50
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0454 - accuracy: 0.9891
# Epoch 22/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0228 - accuracy: 0.9934
# Epoch 23/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0389 - accuracy: 0.9894
# Epoch 24/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0402 - accuracy: 0.9886
# Epoch 25/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0499 - accuracy: 0.9859
# Epoch 26/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0329 - accuracy: 0.9897
# Epoch 27/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0256 - accuracy: 0.9934
# Epoch 28/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0212 - accuracy: 0.9945
# Epoch 29/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0318 - accuracy: 0.9919
# Epoch 30/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0251 - accuracy: 0.9920
# Epoch 31/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0197 - accuracy: 0.9941
# Epoch 32/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0242 - accuracy: 0.9920
# Epoch 33/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0316 - accuracy: 0.9900
# Epoch 34/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0335 - accuracy: 0.9908
# Epoch 35/50
# 200/200 [==============================] - 66s 327ms/step - loss: 0.0753 - accuracy: 0.9839
# Epoch 36/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0298 - accuracy: 0.9898
# Epoch 37/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0313 - accuracy: 0.9920
# Epoch 38/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0355 - accuracy: 0.9906
# Epoch 39/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0293 - accuracy: 0.9923
# Epoch 40/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0284 - accuracy: 0.9928
# Epoch 41/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0414 - accuracy: 0.9880
# Epoch 42/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0266 - accuracy: 0.9937
# Epoch 43/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0363 - accuracy: 0.9887
# Epoch 44/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0276 - accuracy: 0.9934
# Epoch 45/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0141 - accuracy: 0.9950
# Epoch 46/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0296 - accuracy: 0.9919
# Epoch 47/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0220 - accuracy: 0.9955
# Epoch 48/50
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0292 - accuracy: 0.9936
# Epoch 49/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0246 - accuracy: 0.9931
# Epoch 50/50
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0736 - accuracy: 0.9844

# %%
#Accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['val'], loc='upper left')
plt.show()

# %%
# loss
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['val'], loc='upper left')
plt.show()

# %%
import numpy as np

# %%
df1 = pd.DataFrame(np.array(history1.history['val_accuracy'])).add_prefix("m1")
df2 = pd.DataFrame(np.array(history2.history['val_accuracy'])).add_prefix("m2")

# %%
df=pd.concat([df1,df2], sort = False, axis=1)
df
# Out:
#          m10       m20
# 0   0.723594  0.606562
# 1   0.820938  0.736406
# 2   0.939219  0.821719
# 3   0.920313  0.894844
# 4   0.971406  0.905781
# 5   0.971719  0.969375
# 6   0.960938  0.959687
# 7   0.979062  0.973906
# 8   0.981406  0.913281
# 9   0.975000  0.988594
# 10  0.977500  0.969219
# 11  0.974531  0.989531
# 12  0.982969  0.979062
# 13  0.966406  0.990313
# 14  0.967031  0.971875
# 15  0.964844  0.957812
# 16  0.984844  0.984219
# 17  0.976094  0.991250
# 18  0.985313  0.972031
# 19  0.987813  0.992344
# 20  0.973281  0.971406
# 21  0.990000  0.985469
# 22  0.992031  0.996250
# 23  0.983437  0.972500
# 24  0.987813  0.969219
# 25  0.993438  0.985313
# 26  0.975937  0.968281
# 27  0.983437  0.991250
# 28  0.993750  0.990625
# 29  0.989531  0.991406
# 30  0.983125  0.979688
# 31  0.986562  0.955000
# 32  0.982031  0.995000
# 33  0.991094  0.993750
# 34  0.958750  0.973281
# 35  0.960781  0.994687
# 36  0.978281  0.992500
# 37  0.991094  0.973437
# 38  0.960781  0.993594
# 39  0.985625  0.988750
# 40  0.988594  0.996094
# 41  0.993750  0.985781
# 42  0.993281  0.976406
# 43  0.984062  0.996875
# 44  0.990156  0.993125
# 45  0.991406  0.994531
# 46  0.992656  0.997813
# 47  0.989375  0.998281
# 48  0.985469  0.990000
# 49  0.990781  0.996562

# %%
# loss
plt.plot(history1.history['val_accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['model1', 'model2'], loc='upper left')
plt.show()

# %%
history3 = model2.fit(vis,
    #steps_per_epoch=num_class,
    #validation_data=val_ds,
    #validation_steps=num_class,
    epochs=50)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 1s 792ms/step - loss: 149.2354 - accuracy: 0.1250
# Epoch 2/50
# 1/1 [==============================] - 0s 114ms/step - loss: 382.4147 - accuracy: 0.2500
# Epoch 3/50
# 1/1 [==============================] - 0s 112ms/step - loss: 363.4347 - accuracy: 0.2500
# Epoch 4/50
# 1/1 [==============================] - 0s 113ms/step - loss: 119.5350 - accuracy: 0.2500
# Epoch 5/50
# 1/1 [==============================] - 0s 112ms/step - loss: 86.8130 - accuracy: 0.2500
# Epoch 6/50
# 1/1 [==============================] - 0s 112ms/step - loss: 38.3272 - accuracy: 0.2500
# Epoch 7/50
# 1/1 [==============================] - 0s 111ms/step - loss: 38.0943 - accuracy: 0.2500
# Epoch 8/50
# 1/1 [==============================] - 0s 114ms/step - loss: 32.5466 - accuracy: 0.5000
# Epoch 9/50
# 1/1 [==============================] - 0s 113ms/step - loss: 27.1469 - accuracy: 0.2500
# Epoch 10/50
# 1/1 [==============================] - 0s 117ms/step - loss: 14.5845 - accuracy: 0.2500
# Epoch 11/50
# 1/1 [==============================] - 0s 121ms/step - loss: 9.4959 - accuracy: 0.2500
# Epoch 12/50
# 1/1 [==============================] - 0s 111ms/step - loss: 6.6437 - accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 0s 110ms/step - loss: 2.1112 - accuracy: 0.7500
# Epoch 14/50
# 1/1 [==============================] - 0s 104ms/step - loss: 5.0129 - accuracy: 0.3750
# Epoch 15/50
# 1/1 [==============================] - 0s 101ms/step - loss: 6.6989 - accuracy: 0.2500
# Epoch 16/50
# 1/1 [==============================] - 0s 100ms/step - loss: 4.4937 - accuracy: 0.3750
# Epoch 17/50
# 1/1 [==============================] - 0s 105ms/step - loss: 4.3434 - accuracy: 0.1250
# Epoch 18/50
# 1/1 [==============================] - 0s 102ms/step - loss: 3.6844 - accuracy: 0.2500
# Epoch 19/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.4915 - accuracy: 0.5000
# Epoch 20/50
# 1/1 [==============================] - 0s 98ms/step - loss: 2.6909 - accuracy: 0.1250
# Epoch 21/50
# 1/1 [==============================] - 0s 100ms/step - loss: 2.5695 - accuracy: 0.3750
# Epoch 22/50
# 1/1 [==============================] - 0s 103ms/step - loss: 2.2346 - accuracy: 0.2500
# Epoch 23/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.3998 - accuracy: 0.6250
# Epoch 24/50
# 1/1 [==============================] - 0s 102ms/step - loss: 2.1148 - accuracy: 0.1250
# Epoch 25/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.2249 - accuracy: 0.5000
# Epoch 26/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.4657 - accuracy: 0.3750
# Epoch 27/50
# 1/1 [==============================] - 0s 104ms/step - loss: 0.8383 - accuracy: 0.8750
# Epoch 28/50
# 1/1 [==============================] - 0s 105ms/step - loss: 0.8245 - accuracy: 0.7500
# Epoch 29/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.1203 - accuracy: 0.5000
# Epoch 30/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.1125 - accuracy: 0.6250
# Epoch 31/50
# 1/1 [==============================] - 0s 105ms/step - loss: 1.3456 - accuracy: 0.3750
# Epoch 32/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.0362 - accuracy: 0.7500
# Epoch 33/50
# 1/1 [==============================] - 0s 104ms/step - loss: 1.1610 - accuracy: 0.6250
# Epoch 34/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.2745 - accuracy: 0.5000
# Epoch 35/50
# 1/1 [==============================] - 0s 100ms/step - loss: 1.1557 - accuracy: 0.6250
# Epoch 36/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.1789 - accuracy: 0.6250
# Epoch 37/50
# 1/1 [==============================] - 0s 102ms/step - loss: 1.2428 - accuracy: 0.5000
# Epoch 38/50
# 1/1 [==============================] - 0s 103ms/step - loss: 0.9832 - accuracy: 0.5000
# Epoch 39/50
# 1/1 [==============================] - 0s 104ms/step - loss: 0.9456 - accuracy: 0.6250
# Epoch 40/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.0781 - accuracy: 0.5000
# Epoch 41/50
# 1/1 [==============================] - 0s 103ms/step - loss: 1.1125 - accuracy: 0.3750
# Epoch 42/50
# 1/1 [==============================] - 0s 115ms/step - loss: 1.1842 - accuracy: 0.2500
# Epoch 43/50
# 1/1 [==============================] - 0s 112ms/step - loss: 1.2308 - accuracy: 0.5000
# Epoch 44/50
# 1/1 [==============================] - 0s 110ms/step - loss: 1.0929 - accuracy: 0.5000
# Epoch 45/50
# 1/1 [==============================] - 0s 102ms/step - loss: 0.8298 - accuracy: 1.0000
# Epoch 46/50
# 1/1 [==============================] - 0s 103ms/step - loss: 0.7844 - accuracy: 1.0000
# Epoch 47/50
# 1/1 [==============================] - 0s 98ms/step - loss: 0.8871 - accuracy: 0.7500
# Epoch 48/50
# 1/1 [==============================] - 0s 100ms/step - loss: 0.8883 - accuracy: 0.6250
# Epoch 49/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.1074 - accuracy: 0.6250
# Epoch 50/50
# 1/1 [==============================] - 0s 100ms/step - loss: 0.7646 - accuracy: 0.7500

# %%
y_pred_test = model2.predict(vis)
y_pred_test_labels = np.argmax(y_pred_test, axis=1)
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
y_pred_test_labels
# Out:
# array([2, 0, 3, 2, 1, 0, 3, 1], dtype=int64)
